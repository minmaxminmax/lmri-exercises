# %% [markdown]
# #Caracterização do feixe de radiação do irradiador de Co-60 "Eldorado" <br /> *  Perfil vertical do feixe do irradiador *#

# %% [markdown]
# __Data:__ 11 de Julho 2014
# __Autor:__ Gonçalo Carvalhal

# %% [markdown]
# ##1 Objectivos##

# %% [markdown]
#  Observar o perfil horizontal do feixe do irradiador

# %% [markdown]
# ##2 Referências##

# %% [markdown]
# ##3 Equipamento e material##

# %% [markdown]
# **Irradiador**
#     Marca e modelo: AECL Eldorado (nº série: 211) **(LMRI_EQ_57)**
#     Fonte radioactiva: Co-60
#     Actividade à data de referência: 1.094E2 TBq (2.956 kCi) @ 25 fev 1998
#
# **Câmara de ionização**
# Marca, tipo e modelo: PTW Farmer M23332 (nº série: 824) **(LMRI_EQ_09)**
# <!-- ![Câmara de ionização PTW Farmer M23332](files/farmer.jpg) -->
#
# **Electrómetro**
# Marca e modelo: PTW UNIDOS (nº série: 10568) **(LMRI_EQ_23)**
#
# **Outros**
# . barómetro digital de precisão Negretti M2236 (nº série: B1151) **(LMRI_EQ_41)**
# . termómetro digital Comark **(LMRI_EQ_36)**
# . micrómetro de interiores de dois pontos Mitutoyo (nº série: 32263) **(LMRI_EQ_40)**
# . cabo eléctrico **(LMRI_EQ_98)**

# %% [markdown]
# ##4 Procedimento##

# %% [markdown]
# ###4.1 Setup experimental###
# Qualidade da radiação: Co-60
# Distância fonte-câmara (SCD): 110 cm
# Tamanho nominal do campo de radiação: 10 cm x 10 cm
# Tempo de irradiação: 60 s
# Potencial eléctrico aplicado à câmara de ionização: 400 V

# %% [markdown]
# ##5 Formulário##

# %% [markdown]
# * Factor de correcção para a pressão atmosférica e temperatura, $C_{PT}$
# $C_{PT} = \frac{273.15 + T}{293.15}\cdot\frac{1013.25}{P}$,
# com $T$ a temperatura (em oC) e com $P$ a pressão atmosférica (em hPa).
#
# <br />
# * Carga de ionização gerada na câmara de ionização em calibração, $Q'$
# $Q' = Q \cdot C_{PT}$,
# com $Q$ a carga de ionização medida (em C) e com $C_{PT}$ o factor de correcção para a pressão atmosférica e temperatura.
#
# <br />
# * Incerteza associada à medição da carga de ionização gerada na câmara de ionização em calibração, $u_{Q'}$
# $u_{Q'} = C_{PT}\sqrt{u_{Q}^{2}+(\frac{Q}{273.15+T})^{2}\cdot u_{T}^{2}+(\frac{Q}{P})^{2}\cdot u_{P}^{2}}$,
# com $C_{PT}$ o factor de correcção para a pressão atmosférica e temperatura, com $Q$ e $u_{Q}$ a carga de ionização medida e a respectiva incerteza associada (em C), com $T$ e $u_{T}$ a temperatura e a respectiva incerteza associada (em oC) e com $P$ e $u_{P}$ a pressão atmosférica e respectiva incerteza associada (em hPa).

# %% [markdown]
# ##6 Cálculos##

# %% [markdown]
# ###Dados###

# %%
# datasets

# datasets: (temperature (oC), atmospheric pressure (hPa), charge (pC))
#0
dataset1 = [
(19.8, 1016.0, 600.5),
(20.0, 1016.0, 600.5),
(19.7, 1016.1, 600.5)
]
#1
dataset2 = [
(20.0, 1016.0, 600.0),
(20.0, 1016.3, 600.0),
(20.0, 1016.0, 600.5)
]
#2
dataset3 = [
(20.2, 1016.2, 597.5),
(19.9, 1016.1, 597.5),
(20.0, 1016.1, 597.5)
]
#3
dataset4 = [
(20.2, 1016, 597.5),
(20.2, 1016, 597.5),
(20.2, 1016, 597.5)
]
#3.5
dataset5 = [
(20.2, 1016.0, 580.5),
(20.2, 1016.0, 580.5),
(20.1, 1016.0, 580.5)
]
#$4
dataset6 = [
(20.3, 1016.0, 492.0),
(20.3, 1015.8, 492.0),
(20.4, 1015.8, 492.0)
]
#4.5
dataset7 = [
(20.5, 1015.7, 377.5),
(20.5, 1015.7, 377.5),
(20.5, 1015.8, 377.5)
]
#5
dataset8 = [
(20.5, 1015.5, 267.5),
(20.5, 1015.8, 267.5),
(20.4, 1015.8, 267.5)
]
#5.5
dataset9 = [
(21.1, 1014.7, 163.0),
(21.1, 1015.0, 163.0),
(21.1, 1014.7, 163.0)
]
#6
dataset10 = [
(21.0, 1014.7, 122.0),
(20.9, 1014.9, 122.0),
(21.2, 1014.9, 122.0)
]
#6.5
dataset11 = [
(21.1, 1014.8, 95.0),
(21.0, 1014.8, 95.5),
(21.1, 1014.8, 95.0)
]
#7
dataset12 = [
(21.0, 1014.6, 73.5),
(20.9, 1014.6, 73.5),
(21.1, 1014.6, 73.5)
]
#8
dataset13 = [
(21.1, 1014.5, 33.0),
(21.1, 1014.5, 33.0),
(21.1, 1014.5, 33.0)
]
#9
dataset14 = [
(21.0, 1014.7, 11.5),
(21.1, 1014.5, 11.5),
(21.0, 1014.6, 11.5)
]
#10
dataset15 = [
(21.1, 1014.5, 7.5),
(21.0, 1014.5, 7.5),
(21.2, 1014.5, 7.5)
]
#0
dataset16 = [
(21.2, 1014.3, 597.0),
(21.2, 1014.3, 597.0),
(21.1, 1014.6, 597.0)
]
#-1
dataset17 = [
(21.2, 1014.4, 597.5),
(21.2, 1014.5, 597.5),
(21.3, 1014.4, 597.5)
]
#-2
dataset18 = [
(21.2, 1014.4, 596.5),
(21.4, 1014.3, 597.0),
(21.5, 1014.3, 597.0)
]
#-3
dataset19 = [
(21.4, 1014.2, 595.5),
(21.4, 1014.3, 596.0),
(21.4, 1014.3, 596.0)
]
#-3.5
dataset20 = [
(21.4, 1014.4, 595.0),
(21.4, 1014.1, 595.0),
(21.3, 1014.1, 595.0)
]
#-4
dataset21 = [
(21.3, 1014.2, 590.5),
(21.2, 1014.2, 590.5),
(21.4, 1014.2, 590.5)
]
#-4.5
dataset22 = [
(21.4, 1014.3, 549.5),
(21.3, 1014.3, 550.0),
(21.3, 1014.3, 550.0)
]
#-5
dataset23 = [
(21.3, 1014.1, 456.5),
(21.4, 1014.1, 456.5),
(21.4, 1014.0, 456.5)
]
#-5.5
dataset24 = [
(21.3, 1014.1, 334.0),
(21.3, 1014.1, 333.5),
(21.4, 1014.0, 335.5)
]
#-6
dataset25 = [
(21.3, 1014.2, 219.0),
(21.3, 1014.2, 219.5),
(21.4, 1014.2, 219.5)
]
#-6.5
dataset26 = [
(21.3, 1014.0, 140.5),
(21.2, 1014.0, 140.5),
(21.3, 1014.0, 141.0)
]
#-7
dataset27 = [
(21.3, 1014.1, 105.5),
(21.3, 1014.1, 105.5),
(21.4, 1013.9, 105.5)
]
#-8
dataset28 = [
(21.3, 1013.9, 58.5),
(21.3, 1013.9, 58.5),
(21.4, 1013.9, 58.5)
]
#-9
dataset29 = [
(21.4, 1013.9, 24.0),
(21.3, 1014.0, 24.0),
(21.4, 1014.0, 24.0)
]
#-10
dataset30 = [
(21.3, 1014.0, 9.5),
(21.3, 1014.0, 9.5),
(21.4, 1013.9, 9.5)
]

# polar distances
distances = [0, 1, 2, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 8, 9, 10, 0, -1, -2, -3, -3.5, -4, -4.5, -5, -5.5, -6, -6.5, -7, -8, -9, -10]

# %% [markdown]
# ### Análise de dados

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# modules
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d
from scipy.optimize import brentq, bisect
from IPython.display import display, Math, HTML

# %%
# aesthetics
#mpl.rcParams.update({'font.family':'STIXGeneral', 'font.weight':'light', 'mathtext.fontset': 'stix', 'font.size': 18})
pd.options.display.max_colwidth=180
pd.set_option('expand_frame_repr', False)

# %%
# functions
def k_pt(temp, p):
    return ((temp+273.15)/293.15)*(1013.25/p)

def k_ptdataset(dataset):
    return ((dataset[0]+273.15)/293.15) *(1013.25/ dataset[1])

# %%
index = [i for i in range(1,len(dataset1)+1)]
columns = ['temperatura (oC)', 'pressão atmosférica (hPa)', 'carga (pC)',]

df1 = pd.DataFrame(dataset1, columns=columns, index=index)
df2 = pd.DataFrame(dataset2, columns=columns, index=index)
df3 = pd.DataFrame(dataset3, columns=columns, index=index)
df4 = pd.DataFrame(dataset4, columns=columns, index=index)
df5 = pd.DataFrame(dataset5, columns=columns, index=index)
df6 = pd.DataFrame(dataset6, columns=columns, index=index)
df7 = pd.DataFrame(dataset7, columns=columns, index=index)
df8 = pd.DataFrame(dataset8, columns=columns, index=index)
df9 = pd.DataFrame(dataset9, columns=columns, index=index)
df10 = pd.DataFrame(dataset10, columns=columns, index=index)
df11 = pd.DataFrame(dataset11, columns=columns, index=index)
df12 = pd.DataFrame(dataset12, columns=columns, index=index)
df13 = pd.DataFrame(dataset13, columns=columns, index=index)
df14 = pd.DataFrame(dataset14, columns=columns, index=index)
df15 = pd.DataFrame(dataset15, columns=columns, index=index)
df16 = pd.DataFrame(dataset16, columns=columns, index=index)
df17 = pd.DataFrame(dataset17, columns=columns, index=index)
df18 = pd.DataFrame(dataset18, columns=columns, index=index)
df19 = pd.DataFrame(dataset19, columns=columns, index=index)
df20 = pd.DataFrame(dataset20, columns=columns, index=index)
df21 = pd.DataFrame(dataset21, columns=columns, index=index)
df22 = pd.DataFrame(dataset22, columns=columns, index=index)
df23 = pd.DataFrame(dataset23, columns=columns, index=index)
df24 = pd.DataFrame(dataset24, columns=columns, index=index)
df25 = pd.DataFrame(dataset25, columns=columns, index=index)
df26 = pd.DataFrame(dataset26, columns=columns, index=index)
df27 = pd.DataFrame(dataset27, columns=columns, index=index)
df28 = pd.DataFrame(dataset28, columns=columns, index=index)
df29 = pd.DataFrame(dataset29, columns=columns, index=index)
df30 = pd.DataFrame(dataset30, columns=columns, index=index)
    
df1['CPT'] = df1.apply(k_ptdataset, axis=1)
df1['corr_charge (pC)'] = df1['carga (pC)']*df1['CPT']
df2['CPT'] = df2.apply(k_ptdataset, axis=1)
df2['corr_charge (pC)'] = df2['carga (pC)']*df2['CPT']
df3['CPT'] = df3.apply(k_ptdataset, axis=1)
df3['corr_charge (pC)'] = df3['carga (pC)']*df3['CPT']
df4['CPT'] = df4.apply(k_ptdataset, axis=1)
df4['corr_charge (pC)'] = df4['carga (pC)']*df4['CPT']
df5['CPT'] = df5.apply(k_ptdataset, axis=1)
df5['corr_charge (pC)'] = df5['carga (pC)']*df5['CPT']
df6['CPT'] = df6.apply(k_ptdataset, axis=1)
df6['corr_charge (pC)'] = df6['carga (pC)']*df6['CPT']
df7['CPT'] = df7.apply(k_ptdataset, axis=1)
df7['corr_charge (pC)'] = df7['carga (pC)']*df7['CPT']
df8['CPT'] = df8.apply(k_ptdataset, axis=1)
df8['corr_charge (pC)'] = df8['carga (pC)']*df8['CPT']
df9['CPT'] = df9.apply(k_ptdataset, axis=1)
df9['corr_charge (pC)'] = df9['carga (pC)']*df9['CPT']
df10['CPT'] = df10.apply(k_ptdataset, axis=1)
df10['corr_charge (pC)'] = df10['carga (pC)']*df10['CPT']
df11['CPT'] = df11.apply(k_ptdataset, axis=1)
df11['corr_charge (pC)'] = df11['carga (pC)']*df11['CPT']
df12['CPT'] = df12.apply(k_ptdataset, axis=1)
df12['corr_charge (pC)'] = df12['carga (pC)']*df12['CPT']
df13['CPT'] = df13.apply(k_ptdataset, axis=1)
df13['corr_charge (pC)'] = df13['carga (pC)']*df13['CPT']
df14['CPT'] = df14.apply(k_ptdataset, axis=1)
df14['corr_charge (pC)'] = df14['carga (pC)']*df14['CPT']
df15['CPT'] = df15.apply(k_ptdataset, axis=1)
df15['corr_charge (pC)'] = df15['carga (pC)']*df15['CPT']

df16['CPT'] = df16.apply(k_ptdataset, axis=1)
df16['corr_charge (pC)'] = df16['carga (pC)']*df16['CPT']
df17['CPT'] = df17.apply(k_ptdataset, axis=1)
df17['corr_charge (pC)'] = df17['carga (pC)']*df17['CPT']
df18['CPT'] = df18.apply(k_ptdataset, axis=1)
df18['corr_charge (pC)'] = df18['carga (pC)']*df18['CPT']
df19['CPT'] = df19.apply(k_ptdataset, axis=1)
df19['corr_charge (pC)'] = df19['carga (pC)']*df19['CPT']
df20['CPT'] = df20.apply(k_ptdataset, axis=1)
df20['corr_charge (pC)'] = df20['carga (pC)']*df20['CPT']
df21['CPT'] = df21.apply(k_ptdataset, axis=1)
df21['corr_charge (pC)'] = df21['carga (pC)']*df21['CPT']
df22['CPT'] = df15.apply(k_ptdataset, axis=1)
df22['corr_charge (pC)'] = df22['carga (pC)']*df22['CPT']
df23['CPT'] = df15.apply(k_ptdataset, axis=1)
df23['corr_charge (pC)'] = df23['carga (pC)']*df23['CPT']
df24['CPT'] = df24.apply(k_ptdataset, axis=1)
df24['corr_charge (pC)'] = df24['carga (pC)']*df24['CPT']
df25['CPT'] = df15.apply(k_ptdataset, axis=1)
df25['corr_charge (pC)'] = df25['carga (pC)']*df25['CPT']
df26['CPT'] = df26.apply(k_ptdataset, axis=1)
df26['corr_charge (pC)'] = df26['carga (pC)']*df26['CPT']
df27['CPT'] = df27.apply(k_ptdataset, axis=1)
df27['corr_charge (pC)'] = df27['carga (pC)']*df27['CPT']
df28['CPT'] = df28.apply(k_ptdataset, axis=1)
df28['corr_charge (pC)'] = df28['carga (pC)']*df28['CPT']
df29['CPT'] = df29.apply(k_ptdataset, axis=1)
df29['corr_charge (pC)'] = df29['carga (pC)']*df29['CPT']
df30['CPT'] = df30.apply(k_ptdataset, axis=1)
df30['corr_charge (pC)'] = df30['carga (pC)']*df30['CPT']

d = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26, df27, df28, df29, df30]
data = d

for i in data:
    i['CPT'] = np.round(i['CPT'],2)
    i['corr_charge (pC)'] = np.round(i['corr_charge (pC)'],1)

data = pd.concat(data, keys=[i for i in range(1, len(data)+1)], names=['# Repetition'])

# %%
# data summary
m = []
s = []

for index, i in enumerate(d):
    mean = np.round(i['corr_charge (pC)'].mean(), 1)
    var = np.round(i['corr_charge (pC)'].var(), 1)
    sdev = np.round(i['corr_charge (pC)'].std(), 1)
    cv = np.round(sdev/mean, 4)*100
    
    m.append(mean)
    s.append(sdev)
    
    print "dataset",index+1
    print "----------------------------------------------------------------------------------"
    print i
    print "\n"
    print "média:", mean
    #print "variância:", var
    print "desvio-padrão:", sdev
    print "coeficiente de variação (%):", cv
    print "----------------------------------------------------------------------------------"
    print "\n"
# Out:
# dataset 1
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)  CPT  corr_charge (pC)
# 1              19.8                     1016.0       600.5    1             598.5
# 2              20.0                     1016.0       600.5    1             598.9
# 3              19.7                     1016.1       600.5    1             598.2
#
#
# média: 598.5
# desvio-padrão: 0.4
# coeficiente de variação (%): 0.07
# ----------------------------------------------------------------------------------
#
#
# dataset 2
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)  CPT  corr_charge (pC)
# 1                20                     1016.0       600.0    1             598.4
# 2                20                     1016.3       600.0    1             598.2
# ...

# %% [markdown]
# ###Gráficos###

# %%
#plotting
# %matplotlib inline

with mpl.rc_context(rc={'font.family':'sans-serif', 'font.weight':'normal', 'font.size':20}):
    fig, ax = plt.subplots(nrows=1, figsize=(16, 8), dpi=1000)
    ax.set_title('charge measurement', fontsize=20)
    ax.set_xlabel('azimuthal distance (cm)', fontsize=20)
    ax.set_ylabel('charge (pC)', fontsize=20)
    ax.set_xlim([-11, 11])
    ax.set_ylim([0, 620])
   
    for index, i in enumerate(d):
        ax.plot(distances[index], m[index], lw=0.25, ls='-', marker='o', markersize=10, color=[1, 0, 0, .6])
         
with mpl.rc_context(rc={'font.family':'sans-serif', 'font.weight':'normal', 'font.size':20}):
    fig, ax = plt.subplots(nrows=1, figsize=(16, 8), dpi=1000)
    ax.set_title('charge measurement \n (normalization to value at x=0)', fontsize=20)
    ax.set_xlabel('azimuthal distance (cm)', fontsize=20)
    ax.set_ylabel('charge (pC)', fontsize=20)
    ax.set_xlim([-11, 11])
    ax.set_ylim([0, 1.1])
    #TODO: maximum auto
    
    for index, i in enumerate(d):
        ax.plot(distances[index], m[index]/m[-1], lw=0.25, ls='-', marker='o', markersize=10, color=[1, 0, 0, .6])

# %%
# curve fitting
# %matplotlib inline

print("Modelo de ajuste: interpolação")
#display(HTML('Modelo de ajuste :  <a href="http://docs.scipy.org/doc/scipy-0.14.0/reference/tutorial/interpolate.html">b-spline</a>'))
print('\n') 

distances, m = zip(*sorted(zip(distances, m)))

x= distances
y= m
f = interp1d(x, y)

plt.figure(figsize=(16, 8))
plt.plot(distances, m,'o', distances, f(distances),'-')
plt.legend(['data', 'linear'], loc='best')
plt.xlabel('distance (cm)', fontsize=20)
plt.ylabel('charge (pC)', fontsize=20)
plt.xlim([-11, 11])
plt.ylim([0, 620])
plt.grid(b=1)
plt.axhline(y=300, xmin=-11, xmax=11, hold=None)
# Out:
# Modelo de ajuste: interpolação

# %% [markdown]
# ##7 Considerações finais##
# Observa-se que, no caso de colimação do feixe de irradiação de valor nominal 10 cm x 10 cm, a largura horizontal do feixe de irradiação é 10.4 cm.
