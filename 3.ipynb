# %% [markdown]
# #Caracterização do feixe de radiação do irradiador de Co-60 "Eldorado" <br /> * Dependência da carga de ionização com a distância axial da câmara de ionização ao irradiador *#

# %% [markdown]
# __Data:__ 8 de Julho 2014
# __Autor:__ Gonçalo Carvalhal

# %% [markdown]
# ##1 Objectivos##

# %% [markdown]
# Observar a dependência das medidas com a distância axial da câmara de ionização ao irradiador

# %% [markdown]
# ##2 Referências##

# %% [markdown]
# ##3 Material e equipamento##

# %% [markdown]
# **Irradiador**
#     Marca e modelo: AECL Eldorado (nº série: 211) **(LMRI_EQ_57)**
#     Fonte radioactiva: Co-60
#     Actividade à data de referência: 1.094E2 TBq (2.956 kCi) @ 25 fev 1998
#
# **Câmara de ionização**
# Marca, tipo e modelo: PTW Farmer M23332 (nº série: 824) **(LMRI_EQ_09)**
# <!-- ![Câmara de ionização PTW Farmer M23332](files/farmer.jpg) -->
#
# **Electrómetro**
# Marca e modelo: PTW UNIDOS (nº série: 10568) **(LMRI_EQ_23)**
#
# **Outros**
# . barómetro digital de precisão Negretti M2236 (nº série: B1151) **(LMRI_EQ_41)**
# . termómetro digital Comark **(LMRI_EQ_36)**
# . micrómetro de interiores de dois pontos Mitutoyo (nº série: 32263) **(LMRI_EQ_40)**
# . cabo eléctrico **(LMRI_EQ_98)**

# %% [markdown]
# ##4 Procedimento##

# %% [markdown]
# ###4.1 Setup experimental###
# Qualidade da radiação: Co-60
# Distância fonte-câmara (SCD): 100 cm
# Tamanho nominal do campo de radiação: 10 cm x 10 cm
# Tempo de irradiação: 60 s
# Potencial eléctrico aplicado à câmara de ionização: 400 V

# %% [markdown]
# ##5 Formulário##

# %% [markdown]
# * Factor de correcção para a pressão atmosférica e temperatura, $C_{PT}$
# $C_{PT} = \frac{273.15 + T}{293.15}\cdot\frac{1013.25}{P}$,
# com $T$ a temperatura (em oC) e com $P$ a pressão atmosférica (em hPa).
#
# <br />
# * Carga de ionização gerada na câmara de ionização em calibração, $Q'$
# $Q' = Q \cdot C_{PT}$,
# com $Q$ a carga de ionização medida (em C) e com $C_{PT}$ o factor de correcção para a pressão atmosférica e temperatura.
#
# <br />
# * Incerteza associada à medição da carga de ionização gerada na câmara de ionização em calibração, $u_{Q'}$
# $u_{Q'} = C_{PT}\sqrt{u_{Q}^{2}+(\frac{Q}{273.15+T})^{2}\cdot u_{T}^{2}+(\frac{Q}{P})^{2}\cdot u_{P}^{2}}$,
# com $C_{PT}$ o factor de correcção para a pressão atmosférica e temperatura, com $Q$ e $u_{Q}$ a carga de ionização medida e a respectiva incerteza associada (em C), com $T$ e $u_{T}$ a temperatura e a respectiva incerteza associada (em oC) e com $P$ e $u_{P}$ a pressão atmosférica e respectiva incerteza associada (em hPa).

# %% [markdown]
# ##6 Cálculos##

# %% [markdown]
# ###Dados###

# %%
# datasets

# datasets: (temperature (oC), atmospheric pressure (hPa), charge (pC))
dataset1 = [
(20.2, 1017.7, 601.5),
(20.1, 1017.7, 602.0),
(20.1, 1017.8, 602.0),
(20.1, 1017.6, 602.0),
(20.1, 1017.7, 602.0)
]

dataset2 = [
(20.3, 1017.7, 418.0),
(20.3, 1017.7, 418.0),
(20.2, 1017.6, 418.0),
(20.2, 1017.7, 418.0),
(20.3, 1017.6, 418.0)
]

dataset3 = [
(20.3, 1017.7, 306.5),
(20.4, 1017.7, 307.0),
(20.3, 1017.7, 307.0),
(20.3, 1017.7, 306.5),
(20.2, 1017.6, 307.0)
]

dataset4 = [
(20.2, 1017.7, 234.0),
(20.1, 1017.7, 234.0),
(20.1, 1017.8, 234.5),
(20.0, 1017.8, 234.5),
(20.0, 1017.5, 234.5)
]

dataset5 = [
(19.8, 1017.7, 185.0),
(20.0, 1017.7, 185.0),
(19.9, 1017.6, 185.0),
(19.8, 1017.6, 185.0),
(19.9, 1017.6, 185.0)
]

dataset6 = [
(19.5, 1017.5, 149.5),
(19.7, 1017.5, 149.5),
(19.6, 1017.5, 149.5),
(19.7, 1017.5, 149.5),
(19.5, 1017.5, 149.5)
]

dataset7 = [
(19.0, 1017.3, 123.5),
(19.1, 1017.3, 123.5),
(19.2, 1017.4, 123.5),
(18.9, 1017.4, 123.5),
(18.8, 1017.4, 123.5)
]

dataset8 = [
(19.0, 1017.5, 103.5),
(19.1, 1017.5, 103.5),
(19.1, 1017.3, 104.0),
(19.1, 1017.3, 104.0),
(19.1, 1017.4, 103.5)
]

dataset9 = [
(19.2, 1017.5, 88.0),
(19.3, 1017.5, 88.5),
(19.3, 1017.5, 88.5),
(19.1, 1017.4, 88.5),
(19.3, 1017.5, 88.0)
]

dataset10 = [
(19.3, 1017.3, 76.5),
(19.6, 1017.3, 76.5),
(19.4, 1017.4, 76.5),
(19.4, 1017.4, 76.5),
(19.4, 1017.3, 76.0)
]

dataset11 = [
(19.5, 1017.3, 66.5),
(19.5, 1017.3, 66.5),
(19.6, 1017.3, 66.5),
(19.6, 1017.3, 66.5),
(19.4, 1017.3, 66.5)
]

dataset12 = [
(19.4, 1017.3, 937.5),
(19.2, 1017.3, 938.0),
(19.2, 1017.4, 939.0),
(19.2, 1017.4, 939.0),
(19.0, 1017.4, 939.5)
]

dataset13 = [
(19.2, 1017.4, 1673.0),
(19.2, 1017.4, 1674.0),
(19.1, 1017.4, 1674.0),
(18.8, 1017.4, 1674.0),
(19.3, 1017.4, 1674.0)
]

dataset14 = [
(19.2, 1017.3, 744.5),
(19.5, 1017.3, 744.0),
(19.5, 1017.3, 743.5),
(19.4, 1017.3, 744.0),
(19.4, 1017.3, 743.5)
]

dataset15 = [
(19.3, 1017.3, 498.5),
(19.3, 1017.3, 498.5),
(19.3, 1017.3, 498.5),
(19.3, 1017.3, 498.5),
(19.3, 1017.3, 498.5)
]

# distances
distances = [100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 80, 60, 90, 110]

# %% [markdown]
# ### Análise de dados

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# modules
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from IPython.display import display, Math

# %%
# aesthetics
#mpl.rcParams.update({'font.family':'STIXGeneral', 'font.weight':'light', 'mathtext.fontset': 'stix', 'font.size': 18})
pd.options.display.max_colwidth=180
pd.set_option('expand_frame_repr', False)

# %%
# functions
def k_pt(temp, p):
    return ((temp+273.15)/293.15)*(1013.25/p)

def k_ptdataset(dataset):
    return ((dataset[0]+273.15)/293.15) *(1013.25/ dataset[1])

# %%
index = [i for i in range(1,len(dataset1)+1)]
columns = ['temperatura (oC)', 'pressão atmosférica (hPa)', 'carga (pC)',]

df1 = pd.DataFrame(dataset1, columns=columns, index=index)
df2 = pd.DataFrame(dataset2, columns=columns, index=index)
df3 = pd.DataFrame(dataset3, columns=columns, index=index)
df4 = pd.DataFrame(dataset4, columns=columns, index=index)
df5 = pd.DataFrame(dataset5, columns=columns, index=index)
df6 = pd.DataFrame(dataset6, columns=columns, index=index)
df7 = pd.DataFrame(dataset7, columns=columns, index=index)
df8 = pd.DataFrame(dataset8, columns=columns, index=index)
df9 = pd.DataFrame(dataset9, columns=columns, index=index)
df10 = pd.DataFrame(dataset10, columns=columns, index=index)
df11 = pd.DataFrame(dataset11, columns=columns, index=index)
df12 = pd.DataFrame(dataset12, columns=columns, index=index)
df13 = pd.DataFrame(dataset13, columns=columns, index=index)
df14 = pd.DataFrame(dataset14, columns=columns, index=index)
df15 = pd.DataFrame(dataset15, columns=columns, index=index)

df1['CPT'] = df1.apply(k_ptdataset, axis=1)
df1['corr_charge (pC)'] = df1['carga (pC)']*df1['CPT']
df2['CPT'] = df2.apply(k_ptdataset, axis=1)
df2['corr_charge (pC)'] = df2['carga (pC)']*df2['CPT']
df3['CPT'] = df3.apply(k_ptdataset, axis=1)
df3['corr_charge (pC)'] = df3['carga (pC)']*df3['CPT']
df4['CPT'] = df4.apply(k_ptdataset, axis=1)
df4['corr_charge (pC)'] = df4['carga (pC)']*df4['CPT']
df5['CPT'] = df5.apply(k_ptdataset, axis=1)
df5['corr_charge (pC)'] = df5['carga (pC)']*df5['CPT']
df6['CPT'] = df6.apply(k_ptdataset, axis=1)
df6['corr_charge (pC)'] = df6['carga (pC)']*df6['CPT']
df7['CPT'] = df7.apply(k_ptdataset, axis=1)
df7['corr_charge (pC)'] = df7['carga (pC)']*df7['CPT']
df8['CPT'] = df8.apply(k_ptdataset, axis=1)
df8['corr_charge (pC)'] = df8['carga (pC)']*df8['CPT']
df9['CPT'] = df9.apply(k_ptdataset, axis=1)
df9['corr_charge (pC)'] = df9['carga (pC)']*df9['CPT']
df10['CPT'] = df10.apply(k_ptdataset, axis=1)
df10['corr_charge (pC)'] = df10['carga (pC)']*df10['CPT']
df11['CPT'] = df11.apply(k_ptdataset, axis=1)
df11['corr_charge (pC)'] = df11['carga (pC)']*df11['CPT']
df12['CPT'] = df12.apply(k_ptdataset, axis=1)
df12['corr_charge (pC)'] = df12['carga (pC)']*df12['CPT']
df13['CPT'] = df13.apply(k_ptdataset, axis=1)
df13['corr_charge (pC)'] = df13['carga (pC)']*df13['CPT']
df14['CPT'] = df14.apply(k_ptdataset, axis=1)
df14['corr_charge (pC)'] = df14['carga (pC)']*df14['CPT']
df15['CPT'] = df15.apply(k_ptdataset, axis=1)
df15['corr_charge (pC)'] = df15['carga (pC)']*df15['CPT']

d = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]
data = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]

for i in data:
    i['CPT'] = np.round(i['CPT'],2)
    i['corr_charge (pC)'] = np.round(i['corr_charge (pC)'],1)

data = pd.concat(data, keys=[i for i in range(1, len(data)+1)], names=['# Repetition'])

# %%
m = []
s = []

for index, i in enumerate(d):
    mean = np.round(i['corr_charge (pC)'].mean(), 1)
    var = np.round(i['corr_charge (pC)'].var(), 1)
    sdev = np.round(i['corr_charge (pC)'].std(), 1)
    cv = np.round(sdev/mean, 4)*100
    
    m.append(mean)
    s.append(sdev)
    
    print "dataset",index+1
    print "----------------------------------------------------------------------------------"
    print i
    print "\n"
    print "média:", mean
    #print "variância:", var
    print "desvio-padrão:", sdev
    print "coeficiente de variação (%):", cv
    print "----------------------------------------------------------------------------------"
    print "\n"
# Out:
# dataset 1
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)  CPT  corr_charge (pC)
# 1              20.2                     1017.7       601.5    1             599.3
# 2              20.1                     1017.7       602.0    1             599.6
# 3              20.1                     1017.8       602.0    1             599.5
# 4              20.1                     1017.6       602.0    1             599.6
# 5              20.1                     1017.7       602.0    1             599.6
#
#
# média: 599.5
# desvio-padrão: 0.1
# coeficiente de variação (%): 0.02
# ----------------------------------------------------------------------------------
#
#
# dataset 2
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)  CPT  corr_charge (pC)
# 1              20.3                     1017.7         418    1             416.6
# 2              20.3                     1017.7         418    1             416.6
# 3              20.2                     1017.6         418    1             416.5
# 4              20.2                     1017.7         418    1             416.5
# 5              20.3                     1017.6         418    1             416.6
#
#
# média: 416.6
# desvio-padrão: 0.1
# coeficiente de variação (%): 0.02
# ----------------------------------------------------------------------------------
#
#
# dataset 3
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)  CPT  corr_charge (pC)
# 1              20.3                     1017.7       306.5    1             305.5
# 2              20.4                     1017.7       307.0    1             306.1
# 3              20.3                     1017.7       307.0    1             306.0
# 4              20.3                     1017.7       306.5    1             305.5
# 5              20.2                     1017.6       307.0    1             305.9
#
#
# média: 305.8
# desvio-padrão: 0.3
# coeficiente de variação (%): 0.1
# ----------------------------------------------------------------------------------
#
#
# dataset 4
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)  CPT  corr_charge (pC)
# 1              20.2                     1017.7       234.0    1             233.1
# 2              20.1                     1017.7       234.0    1             233.1
# 3              20.1                     1017.8       234.5    1             233.5
# 4              20.0                     1017.8       234.5    1             233.5
# 5              20.0                     1017.5       234.5    1             233.5
#
#
# média: 233.3
# desvio-padrão: 0.2
# coeficiente de variação (%): 0.09
# ----------------------------------------------------------------------------------
#
#
# dataset 5
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.8                     1017.7         185  0.99             184.1
# 2              20.0                     1017.7         185  1.00             184.2
# 3              19.9                     1017.6         185  1.00             184.1
# 4              19.8                     1017.6         185  1.00             184.1
# 5              19.9                     1017.6         185  1.00             184.1
#
#
# média: 184.1
# desvio-padrão: 0.0
# coeficiente de variação (%): 0.0
# ----------------------------------------------------------------------------------
#
#
# dataset 6
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.5                     1017.5       149.5  0.99             148.6
# 2              19.7                     1017.5       149.5  0.99             148.7
# 3              19.6                     1017.5       149.5  0.99             148.7
# 4              19.7                     1017.5       149.5  0.99             148.7
# 5              19.5                     1017.5       149.5  0.99             148.6
#
#
# média: 148.7
# desvio-padrão: 0.1
# coeficiente de variação (%): 0.07
# ----------------------------------------------------------------------------------
#
#
# dataset 7
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.0                     1017.3       123.5  0.99             122.6
# 2              19.1                     1017.3       123.5  0.99             122.6
# 3              19.2                     1017.4       123.5  0.99             122.7
# 4              18.9                     1017.4       123.5  0.99             122.5
# 5              18.8                     1017.4       123.5  0.99             122.5
#
#
# média: 122.6
# desvio-padrão: 0.1
# coeficiente de variação (%): 0.08
# ----------------------------------------------------------------------------------
#
#
# dataset 8
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.0                     1017.5       103.5  0.99             102.7
# 2              19.1                     1017.5       103.5  0.99             102.8
# 3              19.1                     1017.3       104.0  0.99             103.3
# 4              19.1                     1017.3       104.0  0.99             103.3
# 5              19.1                     1017.4       103.5  0.99             102.8
#
#
# média: 103.0
# desvio-padrão: 0.3
# coeficiente de variação (%): 0.29
# ----------------------------------------------------------------------------------
#
#
# dataset 9
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.2                     1017.5        88.0  0.99              87.4
# 2              19.3                     1017.5        88.5  0.99              87.9
# 3              19.3                     1017.5        88.5  0.99              87.9
# 4              19.1                     1017.4        88.5  0.99              87.9
# 5              19.3                     1017.5        88.0  0.99              87.4
#
#
# média: 87.7
# desvio-padrão: 0.3
# coeficiente de variação (%): 0.34
# ----------------------------------------------------------------------------------
#
#
# dataset 10
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.3                     1017.3        76.5  0.99              76.0
# 2              19.6                     1017.3        76.5  0.99              76.1
# 3              19.4                     1017.4        76.5  0.99              76.0
# 4              19.4                     1017.4        76.5  0.99              76.0
# 5              19.4                     1017.3        76.0  0.99              75.5
#
#
# média: 75.9
# desvio-padrão: 0.2
# coeficiente de variação (%): 0.26
# ----------------------------------------------------------------------------------
#
#
# dataset 11
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.5                     1017.3        66.5  0.99              66.1
# 2              19.5                     1017.3        66.5  0.99              66.1
# 3              19.6                     1017.3        66.5  0.99              66.1
# 4              19.6                     1017.3        66.5  0.99              66.1
# 5              19.4                     1017.3        66.5  0.99              66.1
#
#
# média: 66.1
# desvio-padrão: 0.0
# coeficiente de variação (%): 0.0
# ----------------------------------------------------------------------------------
#
#
# dataset 12
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.4                     1017.3       937.5  0.99             931.9
# 2              19.2                     1017.3       938.0  0.99             931.7
# 3              19.2                     1017.4       939.0  0.99             932.6
# 4              19.2                     1017.4       939.0  0.99             932.6
# 5              19.0                     1017.4       939.5  0.99             932.5
#
#
# média: 932.3
# desvio-padrão: 0.4
# coeficiente de variação (%): 0.04
# ----------------------------------------------------------------------------------
#
#
# dataset 13
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.2                     1017.4        1673  0.99            1661.6
# 2              19.2                     1017.4        1674  0.99            1662.6
# 3              19.1                     1017.4        1674  0.99            1662.1
# 4              18.8                     1017.4        1674  0.99            1660.3
# 5              19.3                     1017.4        1674  0.99            1663.2
#
#
# média: 1662.0
# desvio-padrão: 1.1
# coeficiente de variação (%): 0.07
# ----------------------------------------------------------------------------------
#
#
# dataset 14
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.2                     1017.3       744.5  0.99             739.5
# 2              19.5                     1017.3       744.0  0.99             739.8
# 3              19.5                     1017.3       743.5  0.99             739.3
# 4              19.4                     1017.3       744.0  0.99             739.5
# 5              19.4                     1017.3       743.5  0.99             739.0
#
#
# média: 739.4
# desvio-padrão: 0.3
# coeficiente de variação (%): 0.04
# ----------------------------------------------------------------------------------
#
#
# dataset 15
# ----------------------------------------------------------------------------------
#    temperatura (oC)  pressão atmosférica (hPa)  carga (pC)   CPT  corr_charge (pC)
# 1              19.3                     1017.3       498.5  0.99             495.3
# 2              19.3                     1017.3       498.5  0.99             495.3
# 3              19.3                     1017.3       498.5  0.99             495.3
# 4              19.3                     1017.3       498.5  0.99             495.3
# 5              19.3                     1017.3       498.5  0.99             495.3
# média: 495.3
# desvio-padrão: 0.0
# coeficiente de variação (%): 0.0
# ----------------------------------------------------------------------------------

# %% [markdown]
# ###Gráficos###

# %%
#plotting
# %matplotlib inline

with mpl.rc_context(rc={'font.family':'sans-serif', 'font.weight':'normal', 'font.size':20}):
    fig, ax = plt.subplots(nrows=1, figsize=(16, 8), dpi=1000)
    ax.set_title('charge measurement', fontsize=20)
    ax.set_xlabel('distance (cm)', fontsize=20)
    ax.set_ylabel('charge (pC)', fontsize=20)
    ax.set_xlim([50, 310])
   
    for index, i in enumerate(d):
        ax.plot(distances[index], m[index], lw=0.25, ls='-', marker='o', markersize=10, color=[1, 0, 0, .5])

# %%
# curve fitting
# %matplotlib inline

def fitfunc1(x, k):
    return k/(np.power(x, 2))

def fitfunc2(x, k, b):
    return k/(np.power(x, 2)) + b

def fitfunc3(x, k, e):
    return k/(np.power(x, e))

def fitfunc4(x, k, b, e):
    return k/(np.power(x, e)) + b

m, distances = zip(*sorted(zip(m, distances)))
x = distances
y = m

#p, cov = curve_fit(fitfunc2, distances, m, sigma=s)
p, cov = curve_fit(fitfunc3, distances, m)
#yfit = fitfunc1(x, p[0])
#yfit = fitfunc2(x, p[0], p[1])
yfit = fitfunc3(x, p[0], p[1])
#yfit = fitfunc4(x, p[0], p[1], p[2])

perr = np.sqrt(np.diag(cov))
resid = m - yfit
chi2red = np.sum((resid/s)**2)/(len(m) - 3)

print('Modelo de ajuste:')
display(Math(r'y=\frac{k}{x^e}'))
print('\n') 
print('Parâmetros do ajuste:')
display(Math( r'k=%.2f \pm %.2f'   %(p[0], perr[0]) ))
display(Math( r'e=%.2f \pm %.2f'   %(p[1], perr[1]) ))
#display(Math( r'\chi^2_{red}=%.2f' %(chi2red) ))

plt.figure(figsize=(16, 8))
#plt.errorbar(x, y, yerr, fmt = 'bo', ecolor='b', capsize=0)
plt.plot(x, y, 'r', lw=3, ls='', marker='o', markersize=10, alpha=0.8)
plt.plot(x, yfit, '-r', linewidth=2, color=[1, 0, 0, .5])
plt.xlabel('distance (cm)', fontsize=20)
plt.ylabel('charge (pC)', fontsize=20)
plt.legend(['data', 'fit'])
plt.show()
# Out:
# Modelo de ajuste:
# $$y=\frac{k}{x^e}$$
# Parâmetros do ajuste:
# $$k=5986964.90 \pm 41435.22$$
# $$e=2.00 \pm 0.00$$

# %% [markdown]
# ##7 Considerações finais##
# Observa-se que a carga de ionização varia inversamente com o quadrado da distância axial da câmara de ionização ao irradiador, para um mesmo tamnaho de campo de irradiação.
#
# A relação funcional que melhor se ajusta aos resultados das medições é do tipo $y=\frac{k}{x^e}$, com $k=$5986964.90 ± 41435.22 e
# $e$=2.00 ± 0.00.
